# %%
#Corinne Komlodi
#Worked with:
#Time Taken:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image
import scipy.signal as signal

# %%
print('1)')
print('a.')
Mk = .6 #Msun
Lk = .1 #solLum
Rk = .6 #Rsun
Mm = .2 #Msun
Lm = .005 #solLum
Rm = .2 #Rsun
orbit = 7 #days

depth =
# Out:
#   File "<ipython-input-2-f4da7939ec8a>", line 11
#     depth =
#             ^
# SyntaxError: invalid syntax

# %%
Rp = np.arange(.5, 16.5, .5) * 6.3781e8 #range of radii (in km) according to Dr. Google
Rstar = 6.957e10 #km
print('2)')
print('a.')
print('% of earth analogue (1 au and 1 Emass)')
print(100*((6.3781e8+Rstar)/1.496e13))
print('% of earth analogue in the Dr. Google approved ranges of radii and distance')
for i in range(0,len(Rp)):
    a = np.arange(.9, 1.6, .1) * 1.496e13
    p = 100*(Rp[i]+Rstar)/a
    print(Rp[i]/6.3781e8,p)
print('b.')
# Out:
# 2)
# a.
# % of earth analogue (1 au and 1 Emass)
# 0.46930354278074865
# % of earth analogue in the Dr. Google aproved ranges of radii and distance
# 0.5 [0.51907981 0.46717182 0.42470166 0.38930985 0.35936294 0.33369416
#  0.31144788]
# 1.0 [0.52144838 0.46930354 0.42663958 0.39108629 0.36100273 0.33521682
#  0.31286903]
# 1.5 [0.52381696 0.47143526 0.42857751 0.39286272 0.36264251 0.33673947
#  0.31429017]
# 2.0 [0.52618553 0.47356698 0.43051544 0.39463915 0.36428229 0.33826213
#  0.31571132]
# 2.5 [0.52855411 0.4756987  0.43245336 0.39641558 0.36592207 0.33978478
#  0.31713246]
# 3.0 [0.53092268 0.47783041 0.43439129 0.39819201 0.36756186 0.34130744
#  0.31855361]
# 3.5 [0.53329126 0.47996213 0.43632921 0.39996844 0.36920164 0.34283009
#  0.31997475]
# 4.0 [0.53565983 0.48209385 0.43826714 0.40174488 0.37084142 0.34435275
#  0.3213959 ]
# 4.5 [0.53802841 0.48422557 0.44020506 0.40352131 0.37248121 0.34587541
#  0.32281705]
# ...
